# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Siddhardha**

# %% [markdown]
# *student*

# %% [markdown]
# *I was very much interest in data science and coding*

# %% [markdown]
# ### The following code prints 1 to 10 numbers

# %%
for x in range(6):
  print(x+1)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# - one
# - second
# - third
# - 1
# - 2
# - 3
